# %%
x=3
if x%2==False:
    print("x is odd")
elif x%2:
    print("x is even")  
else:
    print("none")
# Out:
# x is even

# %%
x = int(input("Enter a number: "))
print ("x is odd" if x%2==1 else "x is even" if x%2==0 else "none")
# Out:
# x is odd
